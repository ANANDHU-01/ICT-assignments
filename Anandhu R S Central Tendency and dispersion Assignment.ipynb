# %% [markdown]
# # Assignment on central tendency and Dispersion

# %% [markdown]
# import libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# load the data

# %%
data=pd.read_csv('D:\ICT\StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
# [1000 rows x 8 columns]

# %% [markdown]
# no of males and females

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
# students parent level of education

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# avg of scores

# %%
data['total']=data['math score']+data['reading score']+data['writing score']

# %%
data['average']=data['total']/3

# %% [markdown]
# compairing avg scores with gender

# %%
sns.barplot(data['gender'],data['average'])
# Out:
# C:\Users\91989\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='average'>

# %% [markdown]
# comapiring the avg marks with test preperation course

# %%
sns.barplot(data['test preparation course'],data['average'])
# Out:
# C:\Users\91989\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='test preparation course', ylabel='average'>

# %%
data['math score'].var()
# Out:
# 242.4114104104103

# %%
data['writing score'].var()
# Out:
# 231.8426816816816

# %%
data['reading score'].var()
# Out:
# 216.27925425425406

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 10))
fig.suptitle('Comparing Male & Female scores for all three subjects:', fontsize=20) 
# Math score
sns.boxplot(x='gender', y='math score', data=data, ax=ax1)
ax1.title.set_text('Math score vs Gender')
# Reading Score 
sns.boxplot(x='gender', y='reading score', data=data, ax=ax2)
ax2.title.set_text('Reading score vs Gender')
# Writing Score
sns.boxplot(x='gender', y='writing score', data=data, ax=ax3)
ax3.title.set_text('Writing score vs Gender')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
fig.suptitle('Comparing Test Preparation Course vs Scores for all three subjects:', fontsize=20)
# Math
sns.boxplot(x='test preparation course', y='math score', data=data, ax=ax1)
ax1.title.set_text('Math score vs Test Preparation Course')
# Reading
sns.boxplot(x='test preparation course', y='reading score', data=data, ax=ax2)
ax2.title.set_text('Reading score vs Test Preparation Course')
# Writing
sns.boxplot(x='test preparation course', y='writing score', data=data, ax=ax3)
ax3.title.set_text('Writing score vs Test Preparation Course')

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue="gender", y="math score", x="test preparation course", data=data)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="gender", y="reading score", x="test preparation course", data=data)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="gender", y="writing score", x="test preparation course", data=data)
plt.show()

# %%
data['math score'].sort_values(ascending=False)
# Out:
# 999    100
# 996    100
# 515    100
# 517    100
# 516    100
#       ...
# 2       18
# 51      13
# 3       11
# 1        8
# 0        0
# Name: math score, Length: 1000, dtype: int64

# %%
data[data['math score']>=77.0].groupby(['gender','race/ethnicity','math score']).size().reset_index()
# Out:
#      gender race/ethnicity  math score  0
# 0    female        group A          77  1
# 1    female        group A          78  1
# 2    female        group A          82  1
# 3    female        group A          85  1
# 4    female        group A          92  1
# ..      ...            ...         ... ..
# 131    male        group E          93  1
# 132    male        group E          94  3
# 133    male        group E          97  2
# 134    male        group E          99  1
# 135    male        group E         100  2
#
# [136 rows x 4 columns]
